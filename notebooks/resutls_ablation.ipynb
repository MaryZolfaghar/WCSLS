# %%
import pickle
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sys
sys.path.append('..')
from utils.util import *
sns.set_theme()
sns.set_style("whitegrid") #  {darkgrid, whitegrid, dark, white, ticks}
sns.set_context("talk")
# sns.set_context("paper")

# %%
analyze_name = 'analyze_accs'

# %% [markdown]
# ## Read Ratio Results

# %%
with open('../../results/%s_results_mlp.P' %(analyze_name), 'rb') as f:
    mlp_results = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------
lesion_p = 0.1
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion01_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion01_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
# with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
#     rnnlesion01_results_ctxL = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------
lesion_p = 0.3
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion03_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion03_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
# with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
#     rnnlesion03_results_ctxL = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------
lesion_p = 0.5
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion05_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion05_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
# with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
#     rnnlesion05_results_ctxL = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------
lesion_p = 0.7
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion07_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion07_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
# with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
#     rnnlesion07_results_ctxL = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------
lesion_p = 0.9
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion09_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion09_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
# with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
#     rnnlesion09_results_ctxL = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------

# %%
mlp_runs             = dict_to_list(mlp_results, analyze_name)
mlplesion01_runs       = dict_to_list(mlplesion01_results, analyze_name)
mlplesion03_runs       = dict_to_list(mlplesion03_results, analyze_name)
mlplesion05_runs       = dict_to_list(mlplesion05_results, analyze_name)
mlplesion07_runs       = dict_to_list(mlplesion07_results, analyze_name)
mlplesion09_runs       = dict_to_list(mlplesion09_results, analyze_name)

rnnlesion01_runs_ctxF = dict_to_list(rnnlesion01_results_ctxF, analyze_name)
rnnlesion03_runs_ctxF = dict_to_list(rnnlesion03_results_ctxF, analyze_name)
rnnlesion05_runs_ctxF = dict_to_list(rnnlesion05_results_ctxF, analyze_name)
rnnlesion07_runs_ctxF = dict_to_list(rnnlesion07_results_ctxF, analyze_name)
rnnlesion09_runs_ctxF = dict_to_list(rnnlesion09_results_ctxF, analyze_name)


rnnlesion09_runs_ctxF.keys()
# Out:
# dict_keys(['ratio_embed', 'ratio_hidd'])

# %%
val_str = 'ratio_hidd'
ratio_hidds_mlp       = np.asarray(mlp_runs[val_str])
ratio_hidds_mlplesion01 = np.asarray(mlplesion01_runs[val_str])
ratio_hidds_mlplesion03 = np.asarray(mlplesion03_runs[val_str])
ratio_hidds_mlplesion05 = np.asarray(mlplesion05_runs[val_str])
ratio_hidds_mlplesion07 = np.asarray(mlplesion07_runs[val_str])
ratio_hidds_mlplesion09 = np.asarray(mlplesion09_runs[val_str])


ratio_hidds_rnnlesion01_ctxF   = np.asarray(rnnlesion01_runs_ctxF[val_str])
ratio_hidds_rnnlesion03_ctxF   = np.asarray(rnnlesion03_runs_ctxF[val_str])
ratio_hidds_rnnlesion05_ctxF   = np.asarray(rnnlesion05_runs_ctxF[val_str])
ratio_hidds_rnnlesion07_ctxF   = np.asarray(rnnlesion07_runs_ctxF[val_str])
ratio_hidds_rnnlesion09_ctxF   = np.asarray(rnnlesion09_runs_ctxF[val_str])
# Out:
# (20, 21, 2)

# %%
with open('../../results/%s_results_mlp.P' %(analyze_name), 'rb') as f:
    mlp_results = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------
lesion_p = 0.1
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion01_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion01_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion01_results_ctxL = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------
lesion_p = 0.3
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion03_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion03_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion03_results_ctxL = pickle.load(f)
lesion_p = 0.7
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion07_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion07_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion07_results_ctxL = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------

# %%
def runs_to_df(runs_result, lesion_p):
        val_name = "Accuracy"
        cong_train_accs, cong_test_accs = np.asarray(runs_result['cong_train_acc']), \
                                        np.asarray(runs_result['cong_test_acc'])
        incong_train_accs, incong_test_accs = np.asarray(runs_result['incong_train_acc']), \
                                                np.asarray(runs_result['incong_test_acc'])
        train_accs, test_accs = np.asarray(runs_result['train_acc']), np.asarray(runs_result['test_acc'])
        ratio_cong_incong_train = cong_train_accs / incong_train_accs
        ratio_cong_incong_test = cong_test_accs / incong_test_accs

        runs, checkpoints = train_accs.shape

        ratio_tr = pd.DataFrame(ratio_cong_incong_train, columns=np.arange(checkpoints)) 
        ratio_tr.insert(0, 'runs', np.arange(runs))
        df_ratio_cong_incong_acc_tr = pd.melt(ratio_tr, id_vars=['runs'], var_name='steps', value_name=val_name)
        df_ratio_cong_incong_acc_tr['Label'] = 'ratio_accs_train'
        df_ratio_cong_incong_acc_tr['Lesion'] = lesion_p

        tr = pd.DataFrame(train_accs, columns=np.arange(checkpoints)) 
        tr.insert(0, 'runs', np.arange(runs))
        df_train = pd.melt(tr, id_vars=['runs'], var_name='steps', value_name=val_name)
        df_train['Label'] = 'train'
        df_train['Lesion'] = lesion_p

        cong_tr = pd.DataFrame(cong_train_accs, columns=np.arange(checkpoints)) 
        cong_tr.insert(0, 'runs', np.arange(runs))
        df_cong_train = pd.melt(cong_tr, id_vars=['runs'], var_name='steps', value_name=val_name)
        df_cong_train['Label'] = 'cong_train'
        df_cong_train['Lesion'] = lesion_p

        incong_tr = pd.DataFrame(incong_train_accs, columns=np.arange(checkpoints)) 
        incong_tr.insert(0, 'runs', np.arange(runs))
        df_incong_train = pd.melt(incong_tr, id_vars=['runs'], var_name='steps', value_name=val_name)
        df_incong_train['Label'] = 'incong_train'
        df_incong_train['Lesion'] = lesion_p

        dfs = df_train, df_cong_train, df_incong_train,\
              df_ratio_cong_incong_acc_tr
                
        return dfs

def plot_ratio_cong_incong_accs(dfs, ax, color):
        val_name = "Accuracy"
        df_train, df_cong_train, df_incong_train,\
        df_ratio_cong_incong_acc_tr = dfs
        
        ax = sns.lineplot(data=df_ratio_cong_incong_acc_tr,
                                x="steps", y=val_name, hue="Lesion", style="Label",
                                markers=True, dashes=False, err_style="bars", ci=68, palette=[color], ax=ax)

        ax.set_ylim([mi, mx])
        # ax.set_title(sub_title)
        
        return ax

def plot_cong_incong_accs(dfs, ax, colors):
        color_cong, color_incong = colors
        val_name = "Accuracy"
        df_train, df_cong_train, df_incong_train,\
        df_ratio_cong_incong_acc_tr = dfs
        
        ax = sns.lineplot(data=df_cong_train,
                    x="steps", y=val_name, hue="Lesion", style="Label",
                    markers=True, dashes=False, err_style="bars", ci=68, palette=[color_cong], ax=ax) # green
        ax = sns.lineplot(data=df_incong_train,
                    x="steps", y=val_name, hue="Lesion", style="Label",
                    markers=True, dashes=False, err_style="bars", ci=68, palette=[color_incong], ax=ax) # purple

        ax.set_ylim([mi, mx])
        # ax.set_title(sub_title)
        
        return ax

# %% [markdown]
# # RNN

# %%
mi, mx = 0.5, 6.5
figx, figy = 12, 6

# %% [markdown]
# # Lesioned RNN

# %%
fig1, ax1 = plt.subplots(figsize=(figx,figy))
fig2, ax2 = plt.subplots(figsize=(figx,figy))

ctx_order, ctx_order_str, model_str, mfig_str, sub_title = 'first', 'ctxF', 'Lesioned RNN', 'rnnlesion0.1', ''
run_res, val_res = rnnlesion01_acc_runs_ctxF
colors = ['green', 'purple']

dfs = runs_to_df(run_res)
plot_ratio_cong_incong_accs(dfs, ax1, color)
plot_cong_incong_accs(dfs, ax2, colors)

# %%
if ctx_order is not None:
        fig1.suptitle('Accuracy Results - %s - Ax %s' %(model_str, ctx_order), fontweight='bold', fontsize='25')
else:
        fig1.suptitle('Accuracy Results - %s' %(model_str), fontweight='bold', fontsize='25')
plt.tight_layout()
fig_str = '%s_acc_cong_incong_results_%s_hidds' %(ctx_order_str, mfig_str)
fig1.savefig(('../../figures/' + fig_str + '.pdf'), 
        bbox_inches = 'tight', pad_inches = 0)
fig1.savefig(('../../figures/' + fig_str + '.png'), 
        bbox_inches = 'tight', pad_inches = 0)
