# %%
import pickle
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sys
sys.path.append('..')
from utils.util import *
sns.set_theme()
sns.set_style("whitegrid") #  {darkgrid, whitegrid, dark, white, ticks}
sns.set_context("talk")
# sns.set_context("paper")

# %%
analyze_name1 = 'calc_ratio'
analyze_name2 = 'analyze_accs'

# %% [markdown]
# ## Read Ratio Results

# %%
analyze_name = analyze_name1

with open('../../results/%s_results_mlp.P' %(analyze_name), 'rb') as f:
    mlp_results = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------
lesion_p = 0.1
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion01_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion01_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion01_results_ctxL = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------
lesion_p = 0.3
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion03_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion03_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion03_results_ctxL = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------
lesion_p = 0.5
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion05_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion05_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion05_results_ctxL = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------
lesion_p = 0.7
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion07_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion07_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion07_results_ctxL = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------
lesion_p = 0.9
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion09_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion09_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion09_results_ctxL = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------

# %%
mlp_runs             = dict_to_list(mlp_results, analyze_name)
mlplesion01_runs       = dict_to_list(mlplesion01_results, analyze_name)
mlplesion03_runs       = dict_to_list(mlplesion03_results, analyze_name)
mlplesion05_runs       = dict_to_list(mlplesion05_results, analyze_name)
mlplesion07_runs       = dict_to_list(mlplesion07_results, analyze_name)
mlplesion09_runs       = dict_to_list(mlplesion09_results, analyze_name)

rnnlesion01_runs_ctxF = dict_to_list(rnnlesion01_results_ctxF, analyze_name)
rnnlesion03_runs_ctxF = dict_to_list(rnnlesion03_results_ctxF, analyze_name)
rnnlesion05_runs_ctxF = dict_to_list(rnnlesion05_results_ctxF, analyze_name)
rnnlesion07_runs_ctxF = dict_to_list(rnnlesion07_results_ctxF, analyze_name)
rnnlesion09_runs_ctxF = dict_to_list(rnnlesion09_results_ctxF, analyze_name)

rnnlesion01_runs_ctxL = dict_to_list(rnnlesion01_results_ctxL, analyze_name)
rnnlesion03_runs_ctxL = dict_to_list(rnnlesion03_results_ctxL, analyze_name)
rnnlesion05_runs_ctxL = dict_to_list(rnnlesion05_results_ctxL, analyze_name)
rnnlesion07_runs_ctxL = dict_to_list(rnnlesion07_results_ctxL, analyze_name)
rnnlesion09_runs_ctxL = dict_to_list(rnnlesion09_results_ctxL, analyze_name)


rnnlesion09_runs_ctxF.keys()
# Out:
# dict_keys(['ratio_embed', 'ratio_hidd'])

# %%
val_str = 'ratio_hidd'
ratio_hidds_mlp       = np.asarray(mlp_runs[val_str])
ratio_hidds_mlplesion01 = np.asarray(mlplesion01_runs[val_str])
ratio_hidds_mlplesion03 = np.asarray(mlplesion03_runs[val_str])
ratio_hidds_mlplesion05 = np.asarray(mlplesion05_runs[val_str])
ratio_hidds_mlplesion07 = np.asarray(mlplesion07_runs[val_str])
ratio_hidds_mlplesion09 = np.asarray(mlplesion09_runs[val_str])


ratio_hidds_rnnlesion01_ctxF   = np.asarray(rnnlesion01_runs_ctxF[val_str])
ratio_hidds_rnnlesion03_ctxF   = np.asarray(rnnlesion03_runs_ctxF[val_str])
ratio_hidds_rnnlesion05_ctxF   = np.asarray(rnnlesion05_runs_ctxF[val_str])
ratio_hidds_rnnlesion07_ctxF   = np.asarray(rnnlesion07_runs_ctxF[val_str])
ratio_hidds_rnnlesion09_ctxF   = np.asarray(rnnlesion09_runs_ctxF[val_str])

ratio_hidds_rnnlesion01_ctxL   = np.asarray(rnnlesion01_runs_ctxL[val_str])
ratio_hidds_rnnlesion03_ctxL   = np.asarray(rnnlesion03_runs_ctxL[val_str])
ratio_hidds_rnnlesion05_ctxL   = np.asarray(rnnlesion05_runs_ctxL[val_str])
ratio_hidds_rnnlesion07_ctxL   = np.asarray(rnnlesion07_runs_ctxL[val_str])
ratio_hidds_rnnlesion09_ctxL   = np.asarray(rnnlesion09_runs_ctxL[val_str])

# %% [markdown]
# # Read ACC results

# %%
analyze_name = analyze_name2

with open('../../results/%s_results_mlp.P' %(analyze_name), 'rb') as f:
    mlp_results = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------
lesion_p = 0.1
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion01_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion01_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion01_results_ctxL = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------
lesion_p = 0.3
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion03_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion03_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion03_results_ctxL = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------
lesion_p = 0.5
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion05_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion05_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion05_results_ctxL = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------
lesion_p = 0.7
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion07_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion07_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion07_results_ctxL = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------
lesion_p = 0.9
# ----------------------
with open('../../results/%s_results_mlp_lesionp%s.P' %(analyze_name, lesion_p), 'rb') as f:
    mlplesion09_results = pickle.load(f)
# ----------------------
ctx_order = 'first'
ctx_order_str = 'ctxF'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion09_results_ctxF = pickle.load(f)
# ----------------------
ctx_order = 'last'
ctx_order_str = 'ctxL'
# ----------------------
with open('../../results/%s_%s_results_rnn_lesionp%s.P' %(analyze_name, ctx_order_str, lesion_p), 'rb') as f:
    rnnlesion09_results_ctxL = pickle.load(f)
# --------------------------------------------------------------------------------------------------------------

# %%
mlp_runs                   = dict_to_list(mlp_results, analyze_name)
mlplesion01_acc_runs       = dict_to_list(mlplesion01_results, analyze_name)
mlplesion03_acc_runs       = dict_to_list(mlplesion03_results, analyze_name)
mlplesion05_acc_runs       = dict_to_list(mlplesion05_results, analyze_name)
mlplesion07_acc_runs       = dict_to_list(mlplesion07_results, analyze_name)
mlplesion09_acc_runs       = dict_to_list(mlplesion09_results, analyze_name)

rnnlesion01_acc_runs_ctxF = dict_to_list(rnnlesion01_results_ctxF, analyze_name)
rnnlesion03_acc_runs_ctxF = dict_to_list(rnnlesion03_results_ctxF, analyze_name)
rnnlesion05_acc_runs_ctxF = dict_to_list(rnnlesion05_results_ctxF, analyze_name)
rnnlesion07_acc_runs_ctxF = dict_to_list(rnnlesion07_results_ctxF, analyze_name)
rnnlesion09_acc_runs_ctxF = dict_to_list(rnnlesion09_results_ctxF, analyze_name)

rnnlesion01_acc_runs_ctxL = dict_to_list(rnnlesion01_results_ctxL, analyze_name)
rnnlesion03_acc_runs_ctxL = dict_to_list(rnnlesion03_results_ctxL, analyze_name)
rnnlesion05_acc_runs_ctxL = dict_to_list(rnnlesion05_results_ctxL, analyze_name)
rnnlesion07_acc_runs_ctxL = dict_to_list(rnnlesion07_results_ctxL, analyze_name)
rnnlesion09_acc_runs_ctxL = dict_to_list(rnnlesion09_results_ctxL, analyze_name)

rnnlesion09_runs_ctxF.keys()
# Out:
# dict_keys(['ratio_embed', 'ratio_hidd'])

# %%
def runs_to_df(runs_result, ratio_hidds, lesion_p):
        cong_train_accs, incong_train_accs = np.asarray(runs_result['cong_train_acc']),\
                                             np.asarray(runs_result['incong_train_acc'])
        # train_accs = np.asarray(runs_result['train_acc'])
        ratio_acc_train = cong_train_accs / incong_train_accs

        runs, checkpoints = cong_train_accs.shape

        ratio_hidd = pd.DataFrame(ratio_hidds, columns=np.arange(checkpoints)) 
        ratio_hidd.insert(0, 'runs', np.arange(runs))
        df_ratio_hidds = pd.melt(ratio_hidd, id_vars=['runs'], var_name='steps', value_name="Ratio Dist. (cong/incong)")
        df_ratio_hidds['Label'] = 'ratio_dist_hidds'
        df_ratio_hidds['Lesion'] = lesion_p

        ratio_tr = pd.DataFrame(ratio_acc_train, columns=np.arange(checkpoints)) 
        ratio_tr.insert(0, 'runs', np.arange(runs))
        df_ratio_acc_tr = pd.melt(ratio_tr, id_vars=['runs'], var_name='steps', value_name="Ratio Acc. (cong/incong)")
        df_ratio_acc_tr['Label'] = 'ratio_accs_train'
        df_ratio_acc_tr['Lesion'] = lesion_p

        cong_tr = pd.DataFrame(cong_train_accs, columns=np.arange(checkpoints)) 
        cong_tr.insert(0, 'runs', np.arange(runs))
        df_cong_train = pd.melt(cong_tr, id_vars=['runs'], var_name='steps', value_name="Accuracy")
        df_cong_train['Label'] = 'cong' 
        df_cong_train['Lesion'] = lesion_p

        incong_tr = pd.DataFrame(incong_train_accs, columns=np.arange(checkpoints)) 
        incong_tr.insert(0, 'runs', np.arange(runs))
        df_incong_train = pd.melt(incong_tr, id_vars=['runs'], var_name='steps', value_name="Accuracy")
        df_incong_train['Label'] = 'incong'
        df_incong_train['Lesion'] = lesion_p

        frames = [df_cong_train, df_incong_train]
        df_acc_train = pd.concat(frames)

        dfs = df_ratio_hidds, df_ratio_acc_tr, df_acc_train
                
        return dfs
        
def concat_dfs(ctx_order, ctx_order_str, model_name, lesion_ps):
    dfs1 = []
    dfs2 = []
    dfs3 = []
    for i, lesion_p in enumerate(lesion_ps):
        if ctx_order is not None:
            ratio_hidds = eval('ratio_hidds_%slesion0%s_%s' %(model_name, int(lesion_p*10), ctx_order_str))
            run_res = eval('%slesion0%s_acc_runs_%s' %(model_name, int(lesion_p*10), ctx_order_str))
        else:
            ratio_hidds = eval('ratio_hidds_%slesion0%s' %(model_name, int(lesion_p*10)))
            run_res = eval('%slesion0%s_acc_runs' %(model_name, int(lesion_p*10)))
        # ------------
        dfs = runs_to_df(run_res, ratio_hidds, lesion_p)
        df_ratio_hidds, df_ratio_acc_tr, df_acc_train = dfs
        # ------------
        dfs1.append(df_ratio_hidds)
        dfs2.append(df_ratio_acc_tr)
        dfs3.append(df_acc_train)
    dfs_ratio_hidds = pd.concat(dfs1)
    dfs_ratio_acc_tr = pd.concat(dfs2)
    dfs_acc_train = pd.concat(dfs3)

    return dfs_ratio_hidds, dfs_ratio_acc_tr, dfs_acc_train

# %%
def plot_ratio_dists(df, ctx_order, ctx_order_str, model_str, mfig_str, sub_title, ax):
        mi, mx = 0, 5
        val_name = "Ratio Dist. (cong/incong)"
        
        ax = sns.lineplot(data=df,
                                x="steps", y=val_name, hue="Lesion", palette="flare",
                                marker="o", dashes=False, err_style="bars", ci=68, ax=ax)

        ax.set_ylim([mi, mx])
        ax.set_title(sub_title)
        if ctx_order is not None:
                fig.suptitle('Ratio Distance - %s - Ax %s' %(model_str, ctx_order), fontweight='bold', fontsize='25')
        else:
                fig.suptitle('Ratio Distance - %s' %(model_str), fontweight='bold', fontsize='25')

        plt.tight_layout()

        fig_str = '%s_ratio_dists_ablation_results_%s' %(ctx_order_str, mfig_str)
        fig.savefig(('../../figures/' + fig_str + '.pdf'), 
                        bbox_inches = 'tight', pad_inches = 0)
        fig.savefig(('../../figures/' + fig_str + '.png'), 
                        bbox_inches = 'tight', pad_inches = 0)  
        return ax

def plot_ratio_accs(df, ctx_order, ctx_order_str, model_str, mfig_str, sub_title, ax):
        mi, mx = 0, 5
        val_name = "Ratio Acc. (cong/incong)"
        
        ax = sns.lineplot(data=df,
                                x="steps", y=val_name, hue="Lesion", palette="flare", 
                                marker='o', dashes=False, err_style="bars", ci=68, ax=ax)
        ax.set_ylim([mi, mx])
        ax.set_title(sub_title)
        if ctx_order is not None:
                fig.suptitle('Ratio Accuracy - %s - Ax %s' %(model_str, ctx_order), fontweight='bold', fontsize='25')
        else:
                fig.suptitle('Ratio Accuracy - %s' %(model_str), fontweight='bold', fontsize='25')
        plt.tight_layout()

        fig_str = '%s_ratio_accs_ablation_results_%s' %(ctx_order_str, mfig_str)
        fig.savefig(('../../figures/' + fig_str + '.pdf'), 
                        bbox_inches = 'tight', pad_inches = 0)
        fig.savefig(('../../figures/' + fig_str + '.png'), 
                        bbox_inches = 'tight', pad_inches = 0)
        return ax

def plot_cong_incong_accs(df, ctx_order, ctx_order_str, model_str, mfig_str, sub_title, ax):
        mi, mx = 0, 2
        val_name = "Accuracy"
        ax = sns.lineplot(data=df,
                    x="steps", y=val_name, hue="Lesion", style='Label', palette="flare", 
                    markers=True, dashes=False, err_style="bars",  ci=68, ax=ax)
        ax.set_ylim([mi, mx])
        ax.set_title(sub_title)  

        if ctx_order is not None:
                fig.suptitle('Accuracy of cong. vs. incong. - %s - Ax %s' %(model_str, ctx_order), fontweight='bold', fontsize='25')
        else:
                fig.suptitle('Accuracy of cong. vs. incong. - %s' %(model_str), fontweight='bold', fontsize='25')
        plt.legend(loc='upper left', fontsize = '13')
        plt.tight_layout()

        fig_str = '%s_cong_incong_accs_ablation_results_%s' %(ctx_order_str, mfig_str)
        fig.savefig(('../../figures/' + fig_str + '.pdf'), 
                        bbox_inches = 'tight', pad_inches = 0)
        fig.savefig(('../../figures/' + fig_str + '.png'), 
                        bbox_inches = 'tight', pad_inches = 0)

        return ax

# %% [markdown]
# # RNN

# %%
figx, figy = 12, 6

# %% [markdown]
# # Lesioned RNN

# %%
ctx_order, ctx_order_str, model_str, mfig_str, sub_title = 'first', 'ctxF', 'Lesioned RNN', 'rnnlesionall', ''
model_name = 'rnn'
lesion_ps = [0.1, 0.3, 0.5, 0.7, 0.9]
dfs_ratio_hidds, dfs_ratio_acc_tr, dfs_acc_train = \
    concat_dfs(ctx_order, ctx_order_str, model_name, lesion_ps)

# %%
fig, ax = plt.subplots(figsize=(figx,figy))
plot_ratio_dists(dfs_ratio_hidds, ctx_order, ctx_order_str, model_str, mfig_str, sub_title, ax)
# Out:
# <AxesSubplot:xlabel='steps', ylabel='Ratio Dist. (cong/incong)'>

# %%
fig, ax = plt.subplots(figsize=(figx,figy))
plot_ratio_accs(dfs_ratio_acc_tr, ctx_order, ctx_order_str, model_str, mfig_str, sub_title, ax)
# Out:
# <AxesSubplot:xlabel='steps', ylabel='Ratio Acc. (cong/incong)'>

# %%
fig, ax = plt.subplots(figsize=(figx,figy))
plot_cong_incong_accs(dfs_acc_train, ctx_order, ctx_order_str, model_str, mfig_str, sub_title, ax)

# %% [markdown]
# ## Ax last

# %%
ctx_order, ctx_order_str, model_str, mfig_str, sub_title = 'last', 'ctxL', 'Lesioned RNN', 'rnnlesionall', ''
model_name = 'rnn'
lesion_ps = [0.1, 0.3, 0.5, 0.7, 0.9]
dfs_ratio_hidds, dfs_ratio_acc_tr, dfs_acc_train = \
    concat_dfs(ctx_order, ctx_order_str, model_name, lesion_ps)

# %%
fig, ax = plt.subplots(figsize=(figx,figy))
plot_ratio_dists(dfs_ratio_hidds, ctx_order, ctx_order_str, model_str, mfig_str, sub_title, ax)
# Out:
# <AxesSubplot:xlabel='steps', ylabel='Ratio Dist. (cong/incong)'>

# %%
fig, ax = plt.subplots(figsize=(figx,figy))
plot_ratio_accs(dfs_ratio_acc_tr, ctx_order, ctx_order_str, model_str, mfig_str, sub_title, ax)
# Out:
# <AxesSubplot:xlabel='steps', ylabel='Ratio Acc. (cong/incong)'>

# %%
fig, ax = plt.subplots(figsize=(figx,figy))
plot_cong_incong_accs(dfs_acc_train, ctx_order, ctx_order_str, model_str, mfig_str, sub_title, ax)
# Out:
# <AxesSubplot:xlabel='steps', ylabel='Accuracy'>

# %% [markdown]
# # MLP

# %%
ctx_order, ctx_order_str, model_str, mfig_str, sub_title = None, None, 'Lesioned MLP', 'mlplesionall', ''
model_name = 'mlp'
lesion_ps = [0.1, 0.3, 0.5, 0.7, 0.9]
dfs_ratio_hidds, dfs_ratio_acc_tr, dfs_acc_train = \
    concat_dfs(ctx_order, ctx_order_str, model_name, lesion_ps)

# %%
fig, ax = plt.subplots(figsize=(figx,figy))
plot_ratio_dists(dfs_ratio_hidds, ctx_order, ctx_order_str, model_str, mfig_str, sub_title, ax)
# Out:
# <AxesSubplot:xlabel='steps', ylabel='Ratio Dist. (cong/incong)'>

# %%
fig, ax = plt.subplots(figsize=(figx,figy))
plot_ratio_accs(dfs_ratio_acc_tr, ctx_order, ctx_order_str, model_str, mfig_str, sub_title, ax)
# Out:
# <AxesSubplot:xlabel='steps', ylabel='Ratio Acc. (cong/incong)'>

# %%
fig, ax = plt.subplots(figsize=(figx,figy))
plot_cong_incong_accs(dfs_acc_train, ctx_order, ctx_order_str, model_str, mfig_str, sub_title, ax)
# Out:
# <AxesSubplot:xlabel='steps', ylabel='Accuracy'>
